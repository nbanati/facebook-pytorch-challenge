# %% [markdown]
# <a href="https://colab.research.google.com/github/nbanati/facebook-pytorch-challenge/blob/master/Copy_of_Image_Classifier_Project_Modified_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing an AI application
#
# ## **NOTE:**
#
# This is slightly edited notebook to help you with downloaing and loading image datasets. I have left the exercise parts untouched and you have to fill them, ofcourse. If you have any issue with this notebook, feel free to contact me `avinash` on Slack :D
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/Flowers.png?raw=1' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %% [markdown]
# # Tips, Model Performance, Submission Troubleshooting, etc
#
# The amazing people at Slack have compiled an amazing list of tips for this project. Check it here - [link](https://docs.google.com/document/d/1-MCDPOejsn2hq9EoBzMpzGv9jEdtMWoIwjkAa1cVbSM/edit#heading=h.yspy8tt3f0xe)

# %%
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# we need pillow version of 5.3.0
# we will uninstall the older version first
# !pip uninstall -y Pillow
# install the new one
# !pip install Pillow==5.3.0
# import the new one
import PIL
print(PIL.PILLOW_VERSION)
# this should print 5.3.0. If it doesn't, then restart your runtime:
# Menu > Runtime > Restart Runtime
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# 5.3.0

# %%
# Imports here
import os
from torchvision import datasets
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.transforms as transforms
import torchvision.models as models
import torch.optim as optim

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !rm -r flower_data || true
# !unzip -qq flower_data.zip

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# how many samples per batch to load
batch_size = 32

# TODO: Define your transforms for the training and validation sets

data_transforms = transforms.Compose([transforms.RandomRotation(30),
                                     transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])])

# choose the training and test datasets
train_data = datasets.ImageFolder(train_dir,transform=data_transforms)

valid_data = datasets.ImageFolder(valid_dir,transform=valid_transforms)


train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size)

# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json

# !wget -c https://raw.githubusercontent.com/udacity/deep-learning-v2-pytorch/master/intro-to-pytorch/helper.py
import helper

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

  
data_iter = iter(train_loader)
images, labels = next(data_iter)
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
    helper.imshow(images[ii], ax=ax, normalize=True)
# Out:
# --2019-01-08 22:48:26--  https://raw.githubusercontent.com/udacity/deep-learning-v2-pytorch/master/intro-to-pytorch/helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
mymodel=models.resnet18(pretrained=True)
#use_cuda = torch.cuda.is_available()
if torch.cuda.is_available():
    mymodel = mymodel.cuda()

for param in mymodel.parameters():
  param.requires_grad=False
  
from collections import OrderedDict
fc=nn.Sequential(OrderedDict([
    ('fc1',nn.Linear(512,512)),
    ('relu',nn.ReLU()),
    ('fc2',nn.Linear(512,102)),
    ('output',nn.LogSoftmax(dim=1))
]))
  
mymodel.fc=fc

criteria = nn.NLLLoss()
optimizer=optim.Adam(mymodel.fc.parameters(),lr=0.003)
epochs=3
steps=0
running_loss=0
print_every=3
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
mymodel.to(device);
for epoch in range(epochs):
  for images,labels in train_loader:
    steps+=1
    images,labels=images.to(device),labels.to(device)
    optimizer.zero_grad()
    logps=mymodel(images)
    loss=criteria(logps,labels)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    
    if steps % print_every==0:
      mymodel.eval()
      test_loss=0
      accuracy=0
      for images,labels in valid_loader:
        images,labels=images.to(device),labels.to(device)
        logps=mymodel(images)
        loss=criteria(logps,labels)
        test_loss+=loss.item()
        ps=torch.exp(logps)
        top_ps, top_class=ps.topk(1,dim=1)
        equality=top_class==labels.view(*top_class.shape)
        #accuracy+=torch.mean(accuracy.type(torch.FloatTensor)).item()
        accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
      print(f"Epoch {epoch+1}/{epochs}.."
             f"Training loss: {running_loss/print_every:.3f}.. "
              f"Test loss: {test_loss/len(valid_loader):.3f}.. "
             f"Test accuracy: {accuracy/len(valid_loader):.3f}.. ")
        
      running_loss=0
      mymodel.train()
# Out:
# Epoch 1/3..Training loss: 5.029.. Test loss: 4.854.. Test accuracy: 0.026..
# Epoch 1/3..Training loss: 4.798.. Test loss: 4.615.. Test accuracy: 0.032..
# Epoch 1/3..Training loss: 4.592.. Test loss: 4.475.. Test accuracy: 0.065..
# Epoch 1/3..Training loss: 4.380.. Test loss: 4.396.. Test accuracy: 0.090..
# Epoch 1/3..Training loss: 4.507.. Test loss: 4.343.. Test accuracy: 0.100..
# Epoch 1/3..Training loss: 4.383.. Test loss: 4.260.. Test accuracy: 0.101..
# Epoch 1/3..Training loss: 4.192.. Test loss: 4.178.. Test accuracy: 0.127..
# Epoch 1/3..Training loss: 4.076.. Test loss: 4.038.. Test accuracy: 0.173..
# Epoch 1/3..Training loss: 4.156.. Test loss: 3.935.. Test accuracy: 0.202..
# Epoch 1/3..Training loss: 3.992.. Test loss: 3.843.. Test accuracy: 0.194..
# Epoch 1/3..Training loss: 4.178.. Test loss: 3.751.. Test accuracy: 0.224..
# Epoch 1/3..Training loss: 4.015.. Test loss: 3.607.. Test accuracy: 0.232..
# Epoch 1/3..Training loss: 3.623.. Test loss: 3.509.. Test accuracy: 0.232..
# Epoch 1/3..Training loss: 3.613.. Test loss: 3.389.. Test accuracy: 0.283..
# Epoch 1/3..Training loss: 3.568.. Test loss: 3.226.. Test accuracy: 0.323..
# Epoch 1/3..Training loss: 3.630.. Test loss: 3.135.. Test accuracy: 0.281..
# Epoch 1/3..Training loss: 3.342.. Test loss: 2.996.. Test accuracy: 0.282..
# Epoch 1/3..Training loss: 3.131.. Test loss: 2.813.. Test accuracy: 0.345..
# Epoch 1/3..Training loss: 3.007.. Test loss: 2.712.. Test accuracy: 0.368..
# Epoch 1/3..Training loss: 2.676.. Test loss: 2.749.. Test accuracy: 0.335..
# Epoch 1/3..Training loss: 3.264.. Test loss: 2.559.. Test accuracy: 0.391..
# Epoch 1/3..Training loss: 2.538.. Test loss: 2.489.. Test accuracy: 0.405..
# Epoch 1/3..Training loss: 2.695.. Test loss: 2.421.. Test accuracy: 0.424..
# Epoch 1/3..Training loss: 2.861.. Test loss: 2.241.. Test accuracy: 0.469..
# Epoch 1/3..Training loss: 2.516.. Test loss: 2.240.. Test accuracy: 0.456..
# Epoch 1/3..Training loss: 2.666.. Test loss: 2.158.. Test accuracy: 0.462..
# Epoch 1/3..Training loss: 2.409.. Test loss: 2.043.. Test accuracy: 0.488..
# Epoch 1/3..Training loss: 2.455.. Test loss: 1.964.. Test accuracy: 0.516..
# Epoch 1/3..Training loss: 2.223.. Test loss: 1.921.. Test accuracy: 0.529..
# Epoch 1/3..Training loss: 2.367.. Test loss: 1.843.. Test accuracy: 0.565..
# Epoch 1/3..Training loss: 2.362.. Test loss: 1.846.. Test accuracy: 0.564..
# Epoch 1/3..Training loss: 2.440.. Test loss: 1.846.. Test accuracy: 0.549..
# Epoch 1/3..Training loss: 2.389.. Test loss: 1.862.. Test accuracy: 0.542..
# Epoch 1/3..Training loss: 2.577.. Test loss: 1.773.. Test accuracy: 0.559..
# Epoch 1/3..Training loss: 2.008.. Test loss: 1.790.. Test accuracy: 0.545..
# Epoch 1/3..Training loss: 2.165.. Test loss: 1.646.. Test accuracy: 0.574..
# Epoch 1/3..Training loss: 2.017.. Test loss: 1.606.. Test accuracy: 0.568..
# Epoch 1/3..Training loss: 2.041.. Test loss: 1.600.. Test accuracy: 0.558..
# Epoch 1/3..Training loss: 1.992.. Test loss: 1.515.. Test accuracy: 0.614..
# Epoch 1/3..Training loss: 1.932.. Test loss: 1.452.. Test accuracy: 0.634..
# Epoch 1/3..Training loss: 1.978.. Test loss: 1.399.. Test accuracy: 0.636..
# Epoch 1/3..Training loss: 1.755.. Test loss: 1.400.. Test accuracy: 0.625..
# Epoch 1/3..Training loss: 1.773.. Test loss: 1.378.. Test accuracy: 0.632..
# Epoch 1/3..Training loss: 1.846.. Test loss: 1.296.. Test accuracy: 0.661..
# Epoch 1/3..Training loss: 1.890.. Test loss: 1.296.. Test accuracy: 0.648..
# Epoch 1/3..Training loss: 1.782.. Test loss: 1.390.. Test accuracy: 0.610..
# Epoch 1/3..Training loss: 2.070.. Test loss: 1.321.. Test accuracy: 0.631..
# Epoch 1/3..Training loss: 1.897.. Test loss: 1.293.. Test accuracy: 0.658..
# Epoch 1/3..Training loss: 1.655.. Test loss: 1.264.. Test accuracy: 0.651..
# Epoch 1/3..Training loss: 1.671.. Test loss: 1.267.. Test accuracy: 0.649..
# Epoch 1/3..Training loss: 1.591.. Test loss: 1.243.. Test accuracy: 0.670..
# Epoch 1/3..Training loss: 1.548.. Test loss: 1.308.. Test accuracy: 0.640..
# Epoch 1/3..Training loss: 1.794.. Test loss: 1.215.. Test accuracy: 0.666..
# Epoch 1/3..Training loss: 2.064.. Test loss: 1.120.. Test accuracy: 0.709..
# Epoch 1/3..Training loss: 1.722.. Test loss: 1.053.. Test accuracy: 0.721..
# Epoch 1/3..Training loss: 1.565.. Test loss: 1.124.. Test accuracy: 0.704..
# Epoch 1/3..Training loss: 1.741.. Test loss: 1.204.. Test accuracy: 0.671..
# Epoch 1/3..Training loss: 1.221.. Test loss: 1.226.. Test accuracy: 0.649..
# Epoch 1/3..Training loss: 1.507.. Test loss: 1.211.. Test accuracy: 0.674..
# Epoch 1/3..Training loss: 2.004.. Test loss: 1.086.. Test accuracy: 0.704..
# Epoch 1/3..Training loss: 1.371.. Test loss: 1.159.. Test accuracy: 0.701..
# Epoch 1/3..Training loss: 1.842.. Test loss: 1.111.. Test accuracy: 0.710..
# Epoch 1/3..Training loss: 1.500.. Test loss: 1.113.. Test accuracy: 0.698..
# Epoch 1/3..Training loss: 1.379.. Test loss: 1.075.. Test accuracy: 0.700..
# Epoch 1/3..Training loss: 1.387.. Test loss: 0.972.. Test accuracy: 0.753..
# Epoch 1/3..Training loss: 1.412.. Test loss: 1.007.. Test accuracy: 0.729..
# Epoch 1/3..Training loss: 1.534.. Test loss: 0.999.. Test accuracy: 0.721..
# Epoch 1/3..Training loss: 1.523.. Test loss: 0.973.. Test accuracy: 0.719..
# Epoch 2/3..Training loss: 1.268.. Test loss: 0.986.. Test accuracy: 0.715..
# Epoch 2/3..Training loss: 1.536.. Test loss: 0.979.. Test accuracy: 0.716..
# Epoch 2/3..Training loss: 1.214.. Test loss: 1.022.. Test accuracy: 0.704..
# Epoch 2/3..Training loss: 1.226.. Test loss: 0.979.. Test accuracy: 0.746..
# Epoch 2/3..Training loss: 1.207.. Test loss: 0.921.. Test accuracy: 0.760..
# Epoch 2/3..Training loss: 1.238.. Test loss: 0.888.. Test accuracy: 0.748..
# Epoch 2/3..Training loss: 1.151.. Test loss: 0.923.. Test accuracy: 0.731..
# Epoch 2/3..Training loss: 1.314.. Test loss: 0.912.. Test accuracy: 0.741..
# Epoch 2/3..Training loss: 1.152.. Test loss: 0.981.. Test accuracy: 0.714..
# Epoch 2/3..Training loss: 1.294.. Test loss: 0.959.. Test accuracy: 0.732..
# Epoch 2/3..Training loss: 1.119.. Test loss: 0.961.. Test accuracy: 0.718..
# Epoch 2/3..Training loss: 1.613.. Test loss: 0.910.. Test accuracy: 0.735..
# Epoch 2/3..Training loss: 1.014.. Test loss: 0.946.. Test accuracy: 0.731..
# Epoch 2/3..Training loss: 1.317.. Test loss: 0.999.. Test accuracy: 0.697..
# Epoch 2/3..Training loss: 1.333.. Test loss: 0.977.. Test accuracy: 0.714..
# Epoch 2/3..Training loss: 1.184.. Test loss: 0.864.. Test accuracy: 0.759..
# Epoch 2/3..Training loss: 1.436.. Test loss: 0.846.. Test accuracy: 0.757..
# Epoch 2/3..Training loss: 1.201.. Test loss: 0.825.. Test accuracy: 0.770..
# Epoch 2/3..Training loss: 1.314.. Test loss: 0.785.. Test accuracy: 0.792..
# Epoch 2/3..Training loss: 1.116.. Test loss: 0.789.. Test accuracy: 0.787..
# Epoch 2/3..Training loss: 1.197.. Test loss: 0.801.. Test accuracy: 0.772..
# Epoch 2/3..Training loss: 0.857.. Test loss: 0.829.. Test accuracy: 0.779..
# Epoch 2/3..Training loss: 1.188.. Test loss: 0.810.. Test accuracy: 0.786..
# Epoch 2/3..Training loss: 0.986.. Test loss: 0.766.. Test accuracy: 0.794..
# Epoch 2/3..Training loss: 1.254.. Test loss: 0.761.. Test accuracy: 0.795..
# Epoch 2/3..Training loss: 1.091.. Test loss: 0.739.. Test accuracy: 0.808..
# Epoch 2/3..Training loss: 0.902.. Test loss: 0.747.. Test accuracy: 0.817..
# Epoch 2/3..Training loss: 1.116.. Test loss: 0.728.. Test accuracy: 0.789..
# Epoch 2/3..Training loss: 1.050.. Test loss: 0.763.. Test accuracy: 0.780..
# Epoch 2/3..Training loss: 1.261.. Test loss: 0.786.. Test accuracy: 0.777..
# Epoch 2/3..Training loss: 1.135.. Test loss: 0.820.. Test accuracy: 0.760..
# Epoch 2/3..Training loss: 1.140.. Test loss: 0.817.. Test accuracy: 0.765..
# Epoch 2/3..Training loss: 1.050.. Test loss: 0.819.. Test accuracy: 0.783..
# Epoch 2/3..Training loss: 1.238.. Test loss: 0.738.. Test accuracy: 0.802..
# Epoch 2/3..Training loss: 1.276.. Test loss: 0.716.. Test accuracy: 0.801..
# Epoch 2/3..Training loss: 1.219.. Test loss: 0.758.. Test accuracy: 0.781..
# Epoch 2/3..Training loss: 1.030.. Test loss: 0.789.. Test accuracy: 0.784..
# Epoch 2/3..Training loss: 1.193.. Test loss: 0.748.. Test accuracy: 0.805..
# Epoch 2/3..Training loss: 1.087.. Test loss: 0.706.. Test accuracy: 0.819..
# Epoch 2/3..Training loss: 0.938.. Test loss: 0.697.. Test accuracy: 0.804..
# Epoch 2/3..Training loss: 1.199.. Test loss: 0.668.. Test accuracy: 0.813..
# Epoch 2/3..Training loss: 1.355.. Test loss: 0.747.. Test accuracy: 0.781..
# Epoch 2/3..Training loss: 1.275.. Test loss: 0.791.. Test accuracy: 0.764..
# Epoch 2/3..Training loss: 1.046.. Test loss: 0.733.. Test accuracy: 0.794..
# Epoch 2/3..Training loss: 1.136.. Test loss: 0.792.. Test accuracy: 0.784..
# Epoch 2/3..Training loss: 1.071.. Test loss: 0.823.. Test accuracy: 0.764..
# Epoch 2/3..Training loss: 1.302.. Test loss: 0.747.. Test accuracy: 0.784..
# Epoch 2/3..Training loss: 1.257.. Test loss: 0.765.. Test accuracy: 0.778..
# Epoch 2/3..Training loss: 1.384.. Test loss: 0.669.. Test accuracy: 0.815..
# Epoch 2/3..Training loss: 1.192.. Test loss: 0.676.. Test accuracy: 0.817..
# Epoch 2/3..Training loss: 1.210.. Test loss: 0.692.. Test accuracy: 0.808..
# Epoch 2/3..Training loss: 0.703.. Test loss: 0.660.. Test accuracy: 0.823..
# Epoch 2/3..Training loss: 0.989.. Test loss: 0.685.. Test accuracy: 0.806..
# Epoch 2/3..Training loss: 1.206.. Test loss: 0.650.. Test accuracy: 0.810..
# Epoch 2/3..Training loss: 1.065.. Test loss: 0.637.. Test accuracy: 0.806..
# Epoch 2/3..Training loss: 1.098.. Test loss: 0.747.. Test accuracy: 0.792..
# Epoch 2/3..Training loss: 1.381.. Test loss: 0.715.. Test accuracy: 0.800..
# Epoch 2/3..Training loss: 1.490.. Test loss: 0.620.. Test accuracy: 0.829..
# Epoch 2/3..Training loss: 0.848.. Test loss: 0.653.. Test accuracy: 0.807..
# Epoch 2/3..Training loss: 0.939.. Test loss: 0.704.. Test accuracy: 0.796..
# Epoch 2/3..Training loss: 1.024.. Test loss: 0.782.. Test accuracy: 0.783..
# Epoch 2/3..Training loss: 1.321.. Test loss: 0.685.. Test accuracy: 0.810..
# Epoch 2/3..Training loss: 1.204.. Test loss: 0.644.. Test accuracy: 0.814..
# Epoch 2/3..Training loss: 0.950.. Test loss: 0.676.. Test accuracy: 0.796..
# Epoch 2/3..Training loss: 1.127.. Test loss: 0.632.. Test accuracy: 0.816..
# Epoch 2/3..Training loss: 1.006.. Test loss: 0.613.. Test accuracy: 0.832..
# Epoch 2/3..Training loss: 0.935.. Test loss: 0.634.. Test accuracy: 0.832..
# Epoch 2/3..Training loss: 1.151.. Test loss: 0.667.. Test accuracy: 0.821..
# Epoch 3/3..Training loss: 1.103.. Test loss: 0.662.. Test accuracy: 0.808..
# Epoch 3/3..Training loss: 0.788.. Test loss: 0.620.. Test accuracy: 0.823..
# Epoch 3/3..Training loss: 0.945.. Test loss: 0.610.. Test accuracy: 0.832..
# Epoch 3/3..Training loss: 1.007.. Test loss: 0.610.. Test accuracy: 0.837..
# Epoch 3/3..Training loss: 1.091.. Test loss: 0.599.. Test accuracy: 0.831..
# Epoch 3/3..Training loss: 0.755.. Test loss: 0.593.. Test accuracy: 0.834..
# Epoch 3/3..Training loss: 0.893.. Test loss: 0.593.. Test accuracy: 0.833..
# Epoch 3/3..Training loss: 0.943.. Test loss: 0.643.. Test accuracy: 0.811..
# Epoch 3/3..Training loss: 0.626.. Test loss: 0.634.. Test accuracy: 0.826..
# Epoch 3/3..Training loss: 1.148.. Test loss: 0.608.. Test accuracy: 0.824..
# Epoch 3/3..Training loss: 0.909.. Test loss: 0.585.. Test accuracy: 0.826..
# Epoch 3/3..Training loss: 0.651.. Test loss: 0.556.. Test accuracy: 0.832..
# Epoch 3/3..Training loss: 0.865.. Test loss: 0.565.. Test accuracy: 0.839..
# Epoch 3/3..Training loss: 1.079.. Test loss: 0.545.. Test accuracy: 0.830..
# Epoch 3/3..Training loss: 1.170.. Test loss: 0.501.. Test accuracy: 0.851..
# Epoch 3/3..Training loss: 1.093.. Test loss: 0.536.. Test accuracy: 0.851..
# Epoch 3/3..Training loss: 1.027.. Test loss: 0.579.. Test accuracy: 0.828..
# Epoch 3/3..Training loss: 1.212.. Test loss: 0.593.. Test accuracy: 0.837..
# Epoch 3/3..Training loss: 0.956.. Test loss: 0.625.. Test accuracy: 0.824..
# Epoch 3/3..Training loss: 0.873.. Test loss: 0.648.. Test accuracy: 0.805..
# Epoch 3/3..Training loss: 1.074.. Test loss: 0.602.. Test accuracy: 0.823..
# Epoch 3/3..Training loss: 1.183.. Test loss: 0.530.. Test accuracy: 0.853..
# Epoch 3/3..Training loss: 0.825.. Test loss: 0.577.. Test accuracy: 0.841..
# Epoch 3/3..Training loss: 1.098.. Test loss: 0.585.. Test accuracy: 0.829..
# Epoch 3/3..Training loss: 0.918.. Test loss: 0.560.. Test accuracy: 0.841..
# Epoch 3/3..Training loss: 1.152.. Test loss: 0.592.. Test accuracy: 0.835..
# Epoch 3/3..Training loss: 1.022.. Test loss: 0.613.. Test accuracy: 0.836..
# Epoch 3/3..Training loss: 1.035.. Test loss: 0.605.. Test accuracy: 0.834..
# Epoch 3/3..Training loss: 1.151.. Test loss: 0.536.. Test accuracy: 0.867..
# Epoch 3/3..Training loss: 1.026.. Test loss: 0.529.. Test accuracy: 0.854..
# Epoch 3/3..Training loss: 0.919.. Test loss: 0.578.. Test accuracy: 0.836..
# Epoch 3/3..Training loss: 1.057.. Test loss: 0.581.. Test accuracy: 0.822..
# Epoch 3/3..Training loss: 0.790.. Test loss: 0.595.. Test accuracy: 0.833..
# Epoch 3/3..Training loss: 1.008.. Test loss: 0.598.. Test accuracy: 0.841..
# Epoch 3/3..Training loss: 0.807.. Test loss: 0.588.. Test accuracy: 0.842..
# Epoch 3/3..Training loss: 0.868.. Test loss: 0.573.. Test accuracy: 0.836..
# Epoch 3/3..Training loss: 1.140.. Test loss: 0.579.. Test accuracy: 0.829..
# Epoch 3/3..Training loss: 1.039.. Test loss: 0.613.. Test accuracy: 0.822..
# Epoch 3/3..Training loss: 0.673.. Test loss: 0.655.. Test accuracy: 0.808..
# Epoch 3/3..Training loss: 0.962.. Test loss: 0.624.. Test accuracy: 0.817..
# Epoch 3/3..Training loss: 1.120.. Test loss: 0.600.. Test accuracy: 0.822..
# Epoch 3/3..Training loss: 1.046.. Test loss: 0.571.. Test accuracy: 0.829..
# Epoch 3/3..Training loss: 0.863.. Test loss: 0.530.. Test accuracy: 0.856..
# Epoch 3/3..Training loss: 0.835.. Test loss: 0.588.. Test accuracy: 0.836..
# Epoch 3/3..Training loss: 0.773.. Test loss: 0.585.. Test accuracy: 0.835..
# Epoch 3/3..Training loss: 0.735.. Test loss: 0.553.. Test accuracy: 0.856..
# Epoch 3/3..Training loss: 1.093.. Test loss: 0.514.. Test accuracy: 0.869..
# Epoch 3/3..Training loss: 0.799.. Test loss: 0.551.. Test accuracy: 0.846..
# Epoch 3/3..Training loss: 1.344.. Test loss: 0.592.. Test accuracy: 0.826..
# Epoch 3/3..Training loss: 1.023.. Test loss: 0.566.. Test accuracy: 0.840..
# Epoch 3/3..Training loss: 1.039.. Test loss: 0.565.. Test accuracy: 0.838..
# Epoch 3/3..Training loss: 0.974.. Test loss: 0.633.. Test accuracy: 0.812..
# Epoch 3/3..Training loss: 0.837.. Test loss: 0.603.. Test accuracy: 0.827..
# Epoch 3/3..Training loss: 0.866.. Test loss: 0.580.. Test accuracy: 0.846..
# Epoch 3/3..Training loss: 0.809.. Test loss: 0.578.. Test accuracy: 0.845..
# Epoch 3/3..Training loss: 1.272.. Test loss: 0.568.. Test accuracy: 0.839..
# Epoch 3/3..Training loss: 1.191.. Test loss: 0.510.. Test accuracy: 0.858..
# Epoch 3/3..Training loss: 0.920.. Test loss: 0.493.. Test accuracy: 0.873..
# Epoch 3/3..Training loss: 1.086.. Test loss: 0.491.. Test accuracy: 0.875..
# Epoch 3/3..Training loss: 0.725.. Test loss: 0.503.. Test accuracy: 0.870..
# Epoch 3/3..Training loss: 0.905.. Test loss: 0.505.. Test accuracy: 0.872..
# Epoch 3/3..Training loss: 1.096.. Test loss: 0.528.. Test accuracy: 0.852..
# Epoch 3/3..Training loss: 0.725.. Test loss: 0.503.. Test accuracy: 0.849..
# Epoch 3/3..Training loss: 0.928.. Test loss: 0.480.. Test accuracy: 0.866..
# Epoch 3/3..Training loss: 1.037.. Test loss: 0.464.. Test accuracy: 0.873..
# Epoch 3/3..Training loss: 0.736.. Test loss: 0.441.. Test accuracy: 0.886..
# Epoch 3/3..Training loss: 0.794.. Test loss: 0.451.. Test accuracy: 0.878..
# Epoch 3/3..Training loss: 0.694.. Test loss: 0.481.. Test accuracy: 0.863..
# Epoch 3/3..Training loss: 0.902.. Test loss: 0.496.. Test accuracy: 0.852..

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
checkpoint ={'input size':512,
            'output size':10,
            'state_dict':mymodel.state_dict()}

from google.colab import drive
drive.mount('/content/gdrive')

mymodel.class_to_idx =train_data.class_to_idx
mymodel.cpu()
torch.save(checkpoint,'checkpoint.pth')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
model_save_name = 'checkpoint.pth'
path = F"/content/gdrive/My Drive/{model_save_name}" 
torch.save(checkpoint, path)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
  checkpoint=torch.load(filepath)
  mymodel=models.resnet18(pretrained=True)
  if torch.cuda.is_available():
    mymodel = mymodel.cuda()
  for param in mymodel.parameters():
    param.requires_grad=False
  from collections import OrderedDict
  classifier=nn.Sequential(OrderedDict([
      ('fc1',nn.Linear(512,512)),
      ('relu',nn.ReLU()),
      ('fc2',nn.Linear(512,102)),
      ('output',nn.LogSoftmax(dim=1))
    ]))
  mymodel.classifier=classifier
  mymodel.load_state_dict(checkpoint['state_dict'],strict=False)
  return mymodel

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
#image = 'flower_data/valid/1/image_06739.jpg'

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    image = Image.open(image)
    img_transforms = transforms.Compose([transforms.Resize(256),
                                         transforms.CenterCrop(224),
                                         transforms.ToTensor(),
                                         transforms.Normalize([0.485, 0.456, 0.406],
                                                          [0.229, 0.224, 0.225])])
    image = img_transforms(image)
    image = np.array(image)
    print(image.shape)
    return image
  
#image = process_image(image)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    # Process image
    model.cpu()
    img = process_image(image)
    
    # Numpy -> Tensor
    image_tensor = torch.from_numpy(img).type(torch.FloatTensor)
    # Add batch of size 1 to image
    model_input = image_tensor.unsqueeze(0)
    
    # Probs
    probs = torch.exp(model.forward(model_input))
    
    # Top probs
    top_probs, top_labs = probs.topk(5)
    top_probs = top_probs.detach().numpy().tolist()[0] 
    top_labs = top_labs.detach().numpy().tolist()[0]
    
    #model.class_to_idx = train_data['train'].class_to_idx
    #model.class_to_idx = train_data.class_to_idx
    # Convert indices to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labs]
    top_flowers = [label_map[idx_to_class[lab]] for lab in top_labs]
    return top_probs, top_labels, top_flowers
  
probs, classes = predict('flower_data/valid/1/image_06739.jpg', mymodel)
print(probs)
print(classes)
# Out:
# (3, 224, 224)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-33094e88c738> in <module>()
#      30     return top_probs, top_labels, top_flowers
#      31
# ---> 32 probs, classes = predict('flower_data/valid/1/image_06739.jpg', mymodel)
#      33 print(probs)
#      34 print(classes)
#
# <ipython-input-50-33094e88c738> in predict(image_path, model, topk)
#      27                                       model.class_to_idx.items()}
#      28     top_labels = [idx_to_class[lab] for lab in top_labs]
# ---> 29     top_flowers = [label_map[idx_to_class[lab]] for lab in top_labs]
#      30     return top_probs, top_labels, top_flowers
#      31
#
# <ipython-input-50-33094e88c738> in <listcomp>(.0)
#      27                                       model.class_to_idx.items()}
#      28     top_labels = [idx_to_class[lab] for lab in top_labs]
# ---> 29     top_flowers = [label_map[idx_to_class[lab]] for lab in top_labs]
#      30     return top_probs, top_labels, top_flowers
#      31
#
# NameError: name 'label_map' is not defined

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/inference_example.png?raw=1' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def plot_solution(image, model):
    # Set up plot
    plt.figure(figsize = (6,10))
    ax = plt.subplot(2,1,1)
    # Set up title
    flower_num = image.split('/')[1]
    title_ = label_map[flower_num]
    # Plot flower
    img = process_image(image)
    imshow(img, ax, title = title_);
    # Make prediction
    probs, labs, flowers = predict(image, model) 
    # Plot bar chart
    plt.subplot(2,1,2)
    sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
    plt.show()
